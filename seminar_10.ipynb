# %% [markdown]
# <a href="https://colab.research.google.com/github/nastialazareva/ForStudents.TankServer/blob/master/seminar_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Задача №63. Решение в группах
# 1. Изобразите отношение households к population с
# помощью точечного графика

# %%
plt.figure(figsize=(16, 10))
sns.scatterplot(df, x ='households', y ='population');

# %% [markdown]
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график

# %%
sns.relplot(df, x ='longitude', y ='median_house_value', kind ='line');

# %%
plt.figure(figsize=(16, 10))
sns.lineplot(df, x ='longitude', y ='median_house_value');

# %%
sns.set(rc={'figure.figsize':(12, 8)})

# %% [markdown]
# 3. Представить гистограмму по housing_median_age

# %%
sns.histplot(df, x = 'housing_median_age', bins =30);

# %% [markdown]
# 4. Изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
plt.figure(figsize=(16, 10))
sns.histplot(df, x = 'median_house_value', hue = 'housing_median_age');
plt.xticks(range(0, 550000, 25000), rotation=45);
plt.yticks(range(0, 26, 1));

# %% [markdown]
# # Задача №65. Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
# *   Использовать 2-3 точечных графика
# *  Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# *   Использовать PairGrid с типом графика на ваш выбор
# *   Изобразить Heatmap
# *   Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с пингвинами, воспользуйтесь данным скриптом:
#
# penguins = sns.load_dataset("penguins")
#
# penguins.head()

# %%
penguins = sns.load_dataset("penguins")
penguins.sample(20)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 68      Adelie  Torgersen            35.9           16.6              190.0
# 179  Chinstrap      Dream            49.5           19.0              200.0
# 66      Adelie     Biscoe            35.5           16.2              195.0
# 322     Gentoo     Biscoe            47.2           15.5              215.0
# 55      Adelie     Biscoe            41.4           18.6              191.0
# 149     Adelie      Dream            37.8           18.1              193.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 195  Chinstrap      Dream            45.5           17.0              196.0
# 43      Adelie      Dream            44.1           19.7              196.0
# 276     Gentoo     Biscoe            43.8           13.9              208.0
# 286     Gentoo     Biscoe            46.2           14.4              214.0
# 285     Gentoo     Biscoe            49.8           16.8              230.0
# 213  Chinstrap      Dream            46.8           16.5              189.0
# 265     Gentoo     Biscoe            43.6           13.9              217.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 261     Gentoo     Biscoe            49.6           16.0              225.0
# 104     Adelie     Biscoe            37.9           18.6              193.0
# 63      Adelie     Biscoe            41.1           18.2              192.0
# 137     Adelie      Dream            40.2           20.1              200.0
# 293     Gentoo     Biscoe            46.5           14.8              217.0
#
#      body_mass_g     sex
# 68        3050.0  Female
# 179       3800.0    Male
# 66        3350.0  Female
# 322       4975.0  Female
# 55        3700.0    Male
# 149       3750.0    Male
# 116       2900.0  Female
# 195       3500.0  Female
# 43        4400.0    Male
# 276       4300.0  Female
# 286       4650.0     NaN
# 285       5700.0    Male
# 213       3650.0  Female
# 265       4900.0  Female
# 181       4550.0    Male
# 261       5700.0    Male
# 104       2925.0  Female
# 63        4050.0    Male
# 137       3975.0    Male
# 293       5200.0  Female

# %%
sns.scatterplot(penguins, x ='bill_length_mm', y = 'bill_depth_mm', hue = 'species', size = 'sex', style = 'island');

# %%
sns.scatterplot(penguins, x ='flipper_length_mm', y = 'body_mass_g',  hue = 'species', size = 'sex', style = 'island');

# %%
sns.scatterplot(penguins, x ='bill_length_mm', y = 'body_mass_g',  hue = 'species', size = 'sex', style = 'island');

# %% [markdown]
# # Дублирование задачи №65 (что осталось сделать)
# Написать EDA для датасета про пингвинов Необходимо:
# *   Использовать PairGrid с типом графика на ваш выбор
# *   Изобразить Heatmap
# *   Использовать 2-3 гистограммы

# %%
g = sns.PairGrid(penguins[['bill_depth_mm', 'bill_length_mm', 'body_mass_g', 'flipper_length_mm']]);
g.map(sns.scatterplot);

# %%
corr_pg = penguins.corr()
corr_pg
# Out:
# <ipython-input-69-1b76ff1fa902>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_pg = penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(corr_pg, annot = True, cmap = 'coolwarm', linewidths=1);

# %%
sns.histplot(penguins, x ='bill_length_mm');

# %%
sns.histplot(penguins, x = 'bill_depth_mm');

# %%
sns.histplot(penguins, x ='flipper_length_mm');

# %% [markdown]
# # Задача №67. Решение в группах
# Создать новый столбец в таблице с пингвинами, который будет отвечать за показатель длины клюва пингвина.
#
# high - длинный(от 42)
#
# middle - средний(от 35 до 42)
#
# low - маленький(до 35)

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'high_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] >= 35) & (penguins['bill_length_mm'] < 42), 'high_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'high_group'] = 'low'

# %%
penguins.sample(50)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 271     Gentoo     Biscoe            48.5           14.1              220.0
# 258     Gentoo     Biscoe            44.0           13.6              208.0
# 155  Chinstrap      Dream            45.4           18.7              188.0
# 122     Adelie  Torgersen            40.2           17.0              176.0
# 7       Adelie  Torgersen            39.2           19.6              195.0
# 289     Gentoo     Biscoe            50.7           15.0              223.0
# 214  Chinstrap      Dream            45.7           17.0              195.0
# 74      Adelie  Torgersen            35.5           17.5              190.0
# 113     Adelie     Biscoe            42.2           19.5              197.0
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 186  Chinstrap      Dream            49.7           18.6              195.0
# 29      Adelie     Biscoe            40.5           18.9              180.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# 226     Gentoo     Biscoe            45.4           14.6              211.0
# 80      Adelie  Torgersen            34.6           17.2              189.0
# 38      Adelie      Dream            37.6           19.3              181.0
# 36      Adelie      Dream            38.8           20.0              190.0
# 133     Adelie      Dream            37.5           18.5              199.0
# 190  Chinstrap      Dream            46.9           16.6              192.0
# 280     Gentoo     Biscoe            45.3           13.8              208.0
# 286     Gentoo     Biscoe            46.2           14.4              214.0
# 175  Chinstrap      Dream            50.6           19.4              193.0
# 71      Adelie  Torgersen            39.7           18.4              190.0
# 169  Chinstrap      Dream            58.0           17.8              181.0
# 224     Gentoo     Biscoe            47.6           14.5              215.0
# 314     Gentoo     Biscoe            44.5           14.7              214.0
# 243     Gentoo     Biscoe            46.3           15.8              215.0
# 206  Chinstrap      Dream            42.5           17.3              187.0
# 121     Adelie  Torgersen            37.7           19.8              198.0
# 201  Chinstrap      Dream            49.8           17.3              198.0
# 21      Adelie     Biscoe            37.7           18.7              180.0
# 310     Gentoo     Biscoe            47.5           15.0              218.0
# 84      Adelie      Dream            37.3           17.8              191.0
# 166  Chinstrap      Dream            45.9           17.1              190.0
# 298     Gentoo     Biscoe            45.2           13.8              215.0
# 103     Adelie     Biscoe            37.8           20.0              190.0
# 124     Adelie  Torgersen            35.2           15.9              186.0
# 288     Gentoo     Biscoe            43.5           14.2              220.0
# 168  Chinstrap      Dream            50.3           20.0              197.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 316     Gentoo     Biscoe            49.4           15.8              216.0
# 50      Adelie     Biscoe            39.6           17.7              186.0
# 184  Chinstrap      Dream            42.5           16.7              187.0
# 32      Adelie      Dream            39.5           17.8              188.0
# 78      Adelie  Torgersen            36.2           16.1              187.0
# 291     Gentoo     Biscoe            46.4           15.6              221.0
# 33      Adelie      Dream            40.9           18.9              184.0
# 210  Chinstrap      Dream            50.2           18.8              202.0
# 40      Adelie      Dream            36.5           18.0              182.0
# 242     Gentoo     Biscoe            46.5           14.5              213.0
#
#      body_mass_g     sex hith_group high_group
# 271       5300.0    Male        NaN       high
# 258       4350.0  Female        NaN       high
# 155       3525.0  Female        NaN       high
# 122       3450.0  Female        NaN     middle
# 7         4675.0    Male        NaN     middle
# 289       5550.0    Male        NaN       high
# 214       3650.0  Female        NaN       high
# 74        3700.0  Female        NaN     middle
# 113       4275.0    Male        NaN       high
# 0         3750.0    Male        NaN     middle
# 186       3600.0    Male        NaN       high
# 29        3950.0    Male        NaN     middle
# 5         3650.0    Male        NaN     middle
# 226       4800.0  Female        NaN       high
# 80        3200.0  Female        NaN        low
# 38        3300.0  Female        NaN     middle
# 36        3950.0    Male        NaN     middle
# 133       4475.0    Male        NaN     middle
# 190       2700.0  Female        NaN       high
# 280       4200.0  Female        NaN       high
# 286       4650.0     NaN        NaN       high
# 175       3800.0    Male        NaN       high
# 71        3900.0    Male        NaN     middle
# 169       3700.0  Female        NaN       high
# 224       5400.0    Male        NaN       high
# 314       4850.0  Female        NaN       high
# 243       5050.0    Male        NaN       high
# 206       3350.0  Female        NaN       high
# 121       3500.0    Male        NaN     middle
# 201       3675.0  Female        NaN       high
# 21        3600.0    Male        NaN     middle
# 310       4950.0  Female        NaN       high
# 84        3350.0  Female        NaN     middle
# 166       3575.0  Female        NaN       high
# 298       4750.0  Female        NaN       high
# 103       4250.0    Male        NaN     middle
# 124       3050.0  Female        NaN     middle
# 288       4700.0  Female        NaN       high
# 168       3300.0    Male        NaN       high
# 181       4550.0    Male        NaN       high
# 316       4925.0    Male        NaN       high
# 50        3500.0  Female        NaN     middle
# 184       3350.0  Female        NaN       high
# 32        3300.0  Female        NaN     middle
# 78        3550.0  Female        NaN     middle
# 291       5000.0    Male        NaN       high
# 33        3900.0    Male        NaN     middle
# 210       3800.0    Male        NaN       high
# 40        3150.0  Female        NaN     middle
# 242       4400.0  Female        NaN       high

# %% [markdown]
# # Задача №69. Решение в группах
# Изобразить гистограмму по flipper_length_mm с оттенком height_group.
#
# Сделать анализ

# %%
sns.histplot(penguins, x = 'flipper_length_mm', hue = 'high_group');
